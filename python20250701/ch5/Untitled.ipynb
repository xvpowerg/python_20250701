# %%
#作業
#用迴圈根據s 與 e 顯示s ~ e
s = 5
e = 10
#5 6 7 8 9 10
for i in range(s,e+1):
    print(i,end=" ")
# Out:
# 5 6 7 8 9 10

# %%
str1 = "This is 'Python'"
print(str1)
st2 = 'This is my "book"'
print(st2)
# Out:
# This is 'Python'
# This is my "book"

# %%
st3 = """根據消息，AMD 已確認「Zen 6」的 '
CCD 將採用台積電的 N2（2 奈米）製程打造，"
目前該製程已進入風險試產階段，預計今年稍晚可正式進入'量產'。
N2 節點提供的電晶體密度明顯高於現有的 N4P 製程，
而目前的 Zen 5 八核心 CCD 即是基於 N4P 製程生產。
有鑑於此，包括 1usmus 在內的消息來源預估，
AMD 將藉此進一步擴充單一 CCD 的 CPU 核心數。"""
print(st3)
# Out:
# 根據消息，AMD 已確認「Zen 6」的 '
# CCD 將採用台積電的 N2（2 奈米）製程打造，"
# 目前該製程已進入風險試產階段，預計今年稍晚可正式進入'量產'。
# N2 節點提供的電晶體密度明顯高於現有的 N4P 製程，
# 而目前的 Zen 5 八核心 CCD 即是基於 N4P 製程生產。
# 有鑑於此，包括 1usmus 在內的消息來源預估，
# AMD 將藉此進一步擴充單一 CCD 的 CPU 核心數。

# %%
str4 = "ABCDEFG"
#左往右0~n
#右往左-1~-n
print(str4[0])#A
print(str4[2])#C
print(str4[6])#G
print(str4[-1])#G
print(str4[-2])#F
print(str4[-7])#A
# Out:
# A
# C
# G
# G
# F
# A

# %%
str4 = "ABCDEFG"
print(str4[0:3])#大於等於0 尾小於3
print(str4[:3])#預設開頭是0 尾小於3

print(str4[3:])#大於等於3

print(str4[-3:-1])#大於等於-3 尾小於-1

print(str4[::2])

print(str4[::-1])
# Out:
# ABC
# ABC
# DEFG
# EF
# ACEG
# GFEDCBA

# %%
str1 = "This is Python.That is Java,This is SQLite"
newStr = str1.replace("is","__")
print(newStr)
# Out:
# Th__ __ Python.That __ Java,Th__ __ SQLite

# %%
## join
names = ["Ken","Vivin","Lucy"]
newName = ":".join(names)
print(newName)
# Out:
# Ken:Vivin:Lucy

# %%
#split
str4 = "python-java-c++-ruby"
values = str4.split("-")
print(values)
# Out:
# ['python', 'java', 'c++', 'ruby']

# %% [markdown]
# ![image.png](attachment:56506e60-dd24-4d09-a355-d59ba12b580c.png)

# %% [markdown]
# # List VS Tuple
# + tuple 與 list 的差異
#   + 括號不同：
#     + tuple 是用小括號將元素包起來。
#     + list 是用中括號將元素包起來。
# + 元素可否變更：
#    + tuple 決定了元素的內容就不可以變更。
#    + list 可以隨時修改

# %% [markdown]
# ## list 介紹
# + list 內資料用逗號隔開，放置於中括號的範圍內。
#   + list_name = [1,2,3 ]
# + list 可以儲存不同類型的值或項目，如數字和字串。
#   + list_name = [1, 2, ‘Python’, ‘lists’ ]
# + list 內的資料可以進行增加、更新與移除。
# + 可透過.index( )方法取得指定資料的索引。

# %%
myList1 = [1,2,"Ken","Lucy"]
tuple1 = ("Hello",567)
print(myList1)
print(tuple1)
myList1[2] = "Iris"
print(myList1)
tuple1[1] = 99
# Out:
# [1, 2, 'Ken', 'Lucy']
# ('Hello', 567)
# [1, 2, 'Iris', 'Lucy']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 7
#       5 myList1[2] = "Iris"
#       6 print(myList1)
# ----> 7 tuple1[1] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = [3,1,2]
b = [7,8]
c = a + b
print(c)
x = ("Ken","Lucy")
y = ("Iris","Joy")
z = x + y
print(z)
# Out:
# [3, 1, 2, 7, 8]
# ('Ken', 'Lucy', 'Iris', 'Joy')

# %%
nameList = []
print(nameList)
print(len(nameList))#顯示長度
nameList.append(12)#加入List
nameList.append("Ken")
nameList.append("Vivin")
print(nameList)
print(len(nameList))
# Out:
# []
# 0
# [12, 'Ken', 'Vivin']
# 3

# %%
myList1 = ['a','b','c']
myList1.insert(1,'x')
print(myList1)
# Out:
# ['a', 'x', 'b', 'c']
